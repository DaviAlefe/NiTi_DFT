# %% [markdown]
# <a href="https://colab.research.google.com/github/DaviAlefe/NiTi_DFT/blob/master/niti_post_proc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = [8,6]

# %%
ecutCubic = pd.read_csv("/content/drive/My Drive/Davi/niti/testes_de_convergencia/pseudo_paw/conv_test_niti_cubic_paw.csv")
ecutCubic
# Out:
#     Energia de Corte  Energia Total
# 0                 30   -8217.250081
# 1                 40   -8270.774114
# 2                 50   -8277.332861
# 3                 60   -8277.870916
# 4                 70   -8277.928395
# 5                 80   -8278.015529
# 6                 90   -8278.072669
# 7                100   -8278.091863
# 8                110   -8278.096630
# 9                120   -8278.100961
# 10               130   -8278.106272
# 11               140   -8278.110433
# 12               150   -8278.112813

# %%
#teste de convergencia austenita ecutwfc

plt.scatter(ecutCubic.iloc[:,0],ecutCubic.iloc[:,1])
plt.xlabel("Cutoff Energy (Ry)")
plt.ylabel("Total Energy (eV)")
plt.title("Convergence Test: Wavefunctions Cutoff Energy")
# Out:
# Text(0.5, 1.0, 'Convergence Test: Wavefunctions Cutoff Energy')

# %%
kpointsCubic = pd.read_csv('/content/drive/My Drive/Davi/niti/testes_de_convergencia/pseudo_paw/convkpoints_test_niti_cubic_paw.csv')
kpointsCubic
# Out:
#           k-points  Energia Total
# 0      3 3 3 0 0 0   -8278.022855
# 1      4 4 4 0 0 0   -8278.079107
# 2      5 5 5 0 0 0   -8278.003135
# 3      6 6 6 0 0 0   -8278.020349
# 4      7 7 7 0 0 0   -8278.015711
# 5      8 8 8 0 0 0   -8278.015529
# 6      9 9 9 0 0 0   -8278.015716
# 7   10 10 10 0 0 0   -8278.015530
# 8   11 11 11 0 0 0   -8278.015744
# 9   12 12 12 0 0 0   -8278.015786
# 10  13 13 13 0 0 0   -8278.015778
# 11  14 14 14 0 0 0   -8278.015775
# 12  15 15 15 0 0 0   -8278.015742

# %%
#teste de convergencia kpoints austenita

x = range(1,14)
plt.scatter(x, kpointsCubic.iloc[:,1])
plt.xlabel("# of k-points")
plt.ylabel("Total Energy (eV)")
plt.title("Convergence Test: k-points")
# Out:
# Text(0.5, 1.0, 'Convergence Test: k-points')

# %%
ecutrhoCubic = pd.read_csv('/content/drive/My Drive/Davi/niti/testes_de_convergencia/pseudo_paw/convecutrho_test_niti_cubic_paw.csv')
ecutrhoCubic
# Out:
#     Energia de Corte rho  Energia Total
# 0                    400   -8278.092470
# 1                    500   -8278.092178
# 2                    600   -8278.091983
# 3                    700   -8278.091931
# 4                    800   -8278.091891
# 5                    900   -8278.091861
# 6                   1000   -8278.091840
# 7                   1100   -8278.091838
# 8                   1200   -8278.091827
# 9                   1300   -8278.091828
# 10                  1400   -8278.091821
# 11                  1500   -8278.091821
# 12                  1600   -8278.091819
# 13                  1700   -8278.091819
# 14                  1800   -8278.091817
# 15                  1900   -8278.091816
# 16                  2000   -8278.091817

# %%
#teste de convergencia ecutrho austenita

plt.scatter(ecutrhoCubic.iloc[:,0],ecutrhoCubic.iloc[:,1])
plt.xlabel("Cutoff Energy (Ry)")
plt.ylabel("Total Energy (eV)")
plt.title("Convergence Test: Charge Density Cutoff Energy")
# Out:
# Text(0.5, 1.0, 'Convergence Test: Charge Density Cutoff Energy')

# %%
dos = pd.read_csv('/content/drive/My Drive/niti/niti.cubic.phdos.csv')
dos
# Out:
#      Frequency[cm^-1]           DOS        PDOS 1        PDOS 2
# 0           -0.000005  0.000000e+00  0.000000e+00  0.000000e+00
# 1            0.999995  3.547466e-07  1.954200e-07  1.593300e-07
# 2            1.999995  1.418990e-06  7.817800e-07  6.372100e-07
# 3            2.999995  3.192731e-06  1.759200e-06  1.433500e-06
# 4            3.999995  5.675969e-06  3.127900e-06  2.548000e-06
# ..                ...           ...           ...           ...
# 288        287.999995  7.390182e-03  2.210600e-04  7.169100e-03
# 289        288.999995  6.202507e-03  1.406600e-04  6.061900e-03
# 290        289.999995  4.771980e-03  6.896000e-05  4.703000e-03
# 291        290.999995  2.921705e-03  1.304600e-05  2.908700e-03
# 292        291.999995  0.000000e+00  0.000000e+00  0.000000e+00
#
# [293 rows x 4 columns]

# %%
#dos austenita smearing=mv degauss=0.005

Dos = pd.read_csv('/content/drive/My Drive/Davi/resultados/niti.cubic.dos_mvDegauss0.005.csv')
Efermi = 16.383
dos = Dos.iloc[:,1]
E = Dos.iloc[:,0] - Efermi
plt.plot(E, dos)
plt.xlim(-5.5,5)
plt.title('Austenita : smearing=mv, degauss=0.005')
plt.ylabel('DOS')
plt.xlabel('E-E$_{Fermi}$ [eV]')
# Out:
# Text(0.5, 0, 'E-E$_{Fermi}$ [eV]')

# %%
#dos austenita smearing=gauus degauss=0.06

DosGauss = pd.read_csv('/content/drive/My Drive/Davi/resultados/niti.cubic.dos_mvDegauss0.005.csv')
Efermi = 16.414
dos = DosGauss.iloc[:,1]
E = DosGauss.iloc[:,0] - Efermi
plt.plot(E, dos)
plt.xlim(-5.5,5)
plt.title('Austenita : smearing=gauss, degauss=0.06')
plt.ylabel('DOS')
plt.xlabel('E-E$_{Fermi}$ [eV]')
# Out:
# Text(0.5, 0, 'E-E$_{Fermi}$ [eV]')

# %%
#austenita
plt.plot(dos.iloc[:,0], dos.DOS,linewidth=1.5, color="purple", label="Total")
plt.plot(dos.iloc[:,0], dos.iloc[:,2],linewidth=0.5, color="red", label= "Ti")
plt.plot(dos.iloc[:,0], dos.iloc[:,3],linewidth=0.5, color="blue", label= "Ni")
plt.legend()
plt.xlabel("Frequência [cm$^{-1}$]")
plt.ylabel("DOS")
plt.grid(linewidth=0.5, c='grey', ls=':')
plt.xlim(0,300)
plt.ylim(bottom=0)
#plt.savefig("phDOS.niti.cubic.png")
# Out:
# (0.0, 0.0590887930983)

# %%
from google.colab import files
files.download("phDOS.niti.cubic.png")

# %%
fonons = pd.read_csv("/content/drive/My Drive/niti/niti.cubic.freq.csv")
fonons = fonons.iloc[:,1:]
fonons
# Out:
#      xpos      ypos      zpos     band1  ...     band3     band4     band5     band6
# 0     0.0  0.000000  0.000000   -0.0000  ...    0.0000  210.8764  210.8764  210.8764
# 1     0.0  0.033333  0.000000   12.5837  ...   21.2308  210.7467  210.7467  211.0571
# 2     0.0  0.066667  0.000000   25.1222  ...   42.0338  210.3510  210.3510  211.6643
# 3     0.0  0.100000  0.000000   37.5698  ...   61.9310  209.6695  209.6695  212.8969
# 4     0.0  0.133333  0.000000   49.8804  ...   80.3547  208.6713  208.6713  215.0891
# ..    ...       ...       ...       ...  ...       ...       ...       ...       ...
# 136   0.5  0.500000  0.366667  120.3452  ...  129.5979  246.9937  266.6333  266.6333
# 137   0.5  0.500000  0.400000  126.8790  ...  131.9186  254.5836  265.9213  265.9213
# 138   0.5  0.500000  0.433333  131.7622  ...  133.9479  260.2313  265.3660  265.3660
# 139   0.5  0.500000  0.466667  134.7847  ...  135.3229  263.7122  265.0107  265.0107
# ...

# %%
seq = range(1,142)
seq[0]
# Out:
# 1

# %%
#Espectro de fonons austenita
plt.plot(seq, fonons.band1, lw=0.7, c="black")
plt.plot(seq, fonons.band2, lw=0.7, c="black")
plt.plot(seq, fonons.band3, lw=0.7, c="black")
plt.plot(seq, fonons.band4, lw=0.7, c="black")
plt.plot(seq, fonons.band5, lw=0.7, c="black")
plt.plot(seq, fonons.band6, lw=0.7, c="black")
plt.xlim(1,141)
plt.ylim(bottom=0)
plt.ylabel("Frequência [cm$^{-1}$]")
#linhas verticais
plt.plot([16,16],[0,350],ls=':',c="red")
plt.plot([31,31],[0,350],ls=':',c="red")
plt.plot([51,51],[0,350],ls=':',c="red")
plt.plot([81,81],[0,350],ls=':',c="red")
plt.plot([111,111],[0,350],ls=':',c="red")
plt.plot([126,126],[0,350],ls=':',c="red")
plt.xticks([1,16,31,51,81,111,126,141],["$\Gamma$", '$X$','$M$',"$\Gamma$","$R$", "$X$","$M$","$R$"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fe2dd0912b0>,
# ...
#  [Text(0, 0, '$\\Gamma$'),
#   Text(0, 0, '$X$'),
#   Text(0, 0, '$M$'),
#   Text(0, 0, '$\\Gamma$'),
#   Text(0, 0, '$R$'),
#   Text(0, 0, '$X$'),
#   Text(0, 0, '$M$'),
#   Text(0, 0, '$R$')])

# %%
bandas = pd.read_csv('/content/drive/My Drive/niti/niti.cubic.bands.csv')
bandas
# Out:
#      xpos      ypos      zpos   band1  ...  band19  band20  band21  band22
# 0     0.0  0.000000  0.000000 -86.946  ...  19.139  25.083  25.083  25.083
# 1     0.0  0.033333  0.000000 -86.946  ...  19.135  24.966  25.136  25.136
# 2     0.0  0.066667  0.000000 -86.945  ...  19.124  24.642  25.293  25.293
# 3     0.0  0.100000  0.000000 -86.945  ...  19.106  24.173  25.542  25.542
# 4     0.0  0.133333  0.000000 -86.945  ...  19.082  23.621  25.871  25.871
# ..    ...       ...       ...     ...  ...     ...     ...     ...     ...
# 136   0.5  0.500000  0.366667 -86.943  ...  22.997  22.997  23.005  24.668
# 137   0.5  0.500000  0.400000 -86.943  ...  22.806  23.477  23.477  24.598
# 138   0.5  0.500000  0.433333 -86.943  ...  22.647  23.931  23.931  24.536
# 139   0.5  0.500000  0.466667 -86.943  ...  22.545  24.309  24.309  24.492
# 140   0.5  0.500000  0.500000 -86.943  ...  22.509  24.476  24.476  24.476
#
# [141 rows x 25 columns]

# %%
Ef = 16.4141
Efermi = Ef* np.ones(141)
Efermi[140]
# Out:
# 16.4141

# %%
#Espectro de bandas eletrônicas austenita
plt.plot(seq, bandas.band1 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band2 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band3 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band4 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band5 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band6 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band7 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band8 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band9 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band10 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band11 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band12 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band13 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band14 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band15 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band16 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band17 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band18 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band19 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band20 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band21 - Efermi, c='black',lw=1)
plt.plot(seq, bandas.band22 - Efermi, c='black',lw=1)
plt.ylim(-10,20)
plt.xlim(1,141)
plt.ylabel("$E - E_{ Fermi} (eV)$")
plt.plot([1,141],[0, 0], c="red", ls='--',lw=2)
#linhas verticais
plt.plot([16,16],[-15,35],ls=':',c="red")
plt.plot([31,31],[-15,35],ls=':',c="red")
plt.plot([51,51],[-15,35],ls=':',c="red")
plt.plot([81,81],[-15,35],ls=':',c="red")
plt.plot([111,111],[-15,35],ls=':',c="red")
plt.plot([126,126],[-15,35],ls=':',c="red")
#ticks
plt.xticks([1,16,31,51,81,111,126,141],["$\Gamma$", '$X$','$M$',"$\Gamma$","$R$", "$X$","$M$","$R$"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fe2db8f5128>,
# ...
#  [Text(0, 0, '$\\Gamma$'),
#   Text(0, 0, '$X$'),
#   Text(0, 0, '$M$'),
#   Text(0, 0, '$\\Gamma$'),
#   Text(0, 0, '$R$'),
#   Text(0, 0, '$X$'),
#   Text(0, 0, '$M$'),
#   Text(0, 0, '$R$')])

# %%
#martensita
pdosTot = pd.read_csv('/content/drive/My Drive/Davi/resultados/pdos_martensita/niti.monoclinic.pdos.pdos_tot.csv')
pdosTot
# Out:
#         E (eV)   dos(E)   pdos(E)
# 0      -87.108  0.00000   0.00000
# 1      -87.098  0.00000   0.00000
# 2      -87.088  0.00000   0.00000
# 3      -87.078  0.00000   0.00000
# 4      -87.068  0.00000   0.00000
# ...        ...      ...       ...
# 10632   19.212  0.02480   0.02450
# 10633   19.222  0.01930   0.01910
# 10634   19.232  0.01100   0.01080
# 10635   19.242  0.00211   0.00209
# 10636   19.252  0.00000   0.00000
#
# [10637 rows x 3 columns]

# %%
#martensita
Efermi = 16.256
E = pdosTot.iloc[:,0] - Efermi
plt.plot(E,pdosTot.iloc[:,1])
plt.title("Densidade Total de Estados - Martensita")
plt.xlim(-8,4)
plt.ylim(0,15)
plt.ylabel('DOS')
plt.xlabel('E-E$_{Fermi}$ [eV]')
# Out:
# Text(0.5, 0, 'E-E$_{Fermi}$ [eV]')

# %%
#pDOS martensita

Ni1_1s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#1(Ni)_wfc#1(s).csv")
Ni1_2s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#1(Ni)_wfc#2(s).csv")
Ni1_3p = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#1(Ni)_wfc#3(p).csv")
Ni1_4d = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#1(Ni)_wfc#4(d).csv")
Ni2_1s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#2(Ni)_wfc#1(s).csv")
Ni2_2s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#2(Ni)_wfc#2(s).csv")
Ni2_3p = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#2(Ni)_wfc#3(p).csv")
Ni2_4d = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#2(Ni)_wfc#4(d).csv")
Ti1_1s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#3(Ti)_wfc#1(s).csv")
Ti1_2s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#3(Ti)_wfc#2(s).csv")
Ti1_3p = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#3(Ti)_wfc#3(p).csv")
Ti1_4d = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#3(Ti)_wfc#4(d).csv")
Ti2_1s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#4(Ti)_wfc#1(s).csv")
Ti2_2s = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#4(Ti)_wfc#2(s).csv")
Ti2_3p = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#4(Ti)_wfc#3(p).csv")
Ti2_4d = pd.read_csv("/content/drive/My Drive/Davi/niti/dos/pdos/monoclinic/saidas/niti.monoclinic.pdos.dat.pdos_atm#4(Ti)_wfc#4(d).csv")

# %%
Ni1_tot = Ni1_1s.iloc[:,1] + Ni1_2s.iloc[:,1] + Ni1_3p.iloc[:,1] + Ni1_4d.iloc[:,1]
Ni2_tot = Ni2_1s.iloc[:,1] + Ni2_2s.iloc[:,1] + Ni2_3p.iloc[:,1] + Ni2_4d.iloc[:,1]
Ti1_tot = Ti1_1s.iloc[:,1] + Ti1_2s.iloc[:,1] + Ti1_3p.iloc[:,1] + Ti1_4d.iloc[:,1]
Ti2_tot = Ti2_1s.iloc[:,1] + Ti2_2s.iloc[:,1] + Ti2_3p.iloc[:,1] + Ti2_4d.iloc[:,1]

# %%
Efermi = 16.256
E = Ni1_1s.iloc[:,0] - Efermi

plt.plot(E, Ni1_tot, label="Ni")
#plt.plot(E, Ni2_tot, label="Ni2") # Ni1 e Ni2 são iguais, assim como Ti1 e Ti2
plt.plot(E, Ti1_tot, label="Ti")
#plt.plot(E, Ti2_tot, label="Ti2")

plt.xlabel("E-E$_{Fermi}$ [eV]")
plt.ylabel("lDOS")
plt.title("Densidade Local de Estados - Martensita")
plt.legend()
plt.xlim(-8,4)
plt.ylim(0,7)
# Out:
# (0.0, 7.0)

# %%
#bandas martensita

bandsMono = pd.read_csv('/content/drive/My Drive/Davi/niti/bandas/monoclinic/saidas/niti.monoclinic.bands.csv')
bandsMono
# Out:
#      Unnamed: 0      xpos      ypos      zpos  ...  band33  band34  band35  band36
# 0             0  0.000000  0.000000  0.000000  ...  17.812  18.440  18.561  18.764
# 1             1  0.016667  0.003258  0.000000  ...  17.773  18.443  18.559  18.784
# 2             2  0.033333  0.006515  0.000000  ...  17.671  18.451  18.554  18.805
# 3             3  0.050000  0.009773  0.000000  ...  17.534  18.461  18.547  18.786
# 4             4  0.066667  0.013030  0.000000  ...  17.384  18.463  18.546  18.739
# ..          ...       ...       ...       ...  ...     ...     ...     ...     ...
# 198         198  0.500000  0.097727  0.290171  ...  16.875  17.481  18.743  19.042
# 199         199  0.500000  0.097727  0.308306  ...  16.926  17.384  18.771  19.005
# 200         200  0.500000  0.097727  0.326442  ...  16.984  17.291  18.804  18.963
# 201         201  0.500000  0.097727  0.344577  ...  17.050  17.204  18.839  18.920
# ...

# %%
seq = range(1,204)

# %%
for i in range(1,37):
  print(f"plt.plot(seq, bandsMono.band{i}-Efermi, c='black')")
# Out:
# plt.plot(seq, bandsMono.band1-Efermi, c='black')
# plt.plot(seq, bandsMono.band2-Efermi, c='black')
# plt.plot(seq, bandsMono.band3-Efermi, c='black')
# plt.plot(seq, bandsMono.band4-Efermi, c='black')
# plt.plot(seq, bandsMono.band5-Efermi, c='black')
# plt.plot(seq, bandsMono.band6-Efermi, c='black')
# plt.plot(seq, bandsMono.band7-Efermi, c='black')
# plt.plot(seq, bandsMono.band8-Efermi, c='black')
# plt.plot(seq, bandsMono.band9-Efermi, c='black')
# plt.plot(seq, bandsMono.band10-Efermi, c='black')
# plt.plot(seq, bandsMono.band11-Efermi, c='black')
# plt.plot(seq, bandsMono.band12-Efermi, c='black')
# plt.plot(seq, bandsMono.band13-Efermi, c='black')
# plt.plot(seq, bandsMono.band14-Efermi, c='black')
# plt.plot(seq, bandsMono.band15-Efermi, c='black')
# plt.plot(seq, bandsMono.band16-Efermi, c='black')
# plt.plot(seq, bandsMono.band17-Efermi, c='black')
# plt.plot(seq, bandsMono.band18-Efermi, c='black')
# plt.plot(seq, bandsMono.band19-Efermi, c='black')
# ...

# %%
Efermi = 16.256

# %%
plt.plot(seq, bandsMono.band1-Efermi, c='black')
plt.plot(seq, bandsMono.band2-Efermi, c='black')
plt.plot(seq, bandsMono.band3-Efermi, c='black')
plt.plot(seq, bandsMono.band4-Efermi, c='black')
plt.plot(seq, bandsMono.band5-Efermi, c='black')
plt.plot(seq, bandsMono.band6-Efermi, c='black')
plt.plot(seq, bandsMono.band7-Efermi, c='black')
plt.plot(seq, bandsMono.band8-Efermi, c='black')
plt.plot(seq, bandsMono.band9-Efermi, c='black')
plt.plot(seq, bandsMono.band10-Efermi, c='black')
plt.plot(seq, bandsMono.band11-Efermi, c='black')
plt.plot(seq, bandsMono.band12-Efermi, c='black')
plt.plot(seq, bandsMono.band13-Efermi, c='black')
plt.plot(seq, bandsMono.band14-Efermi, c='black')
plt.plot(seq, bandsMono.band15-Efermi, c='black')
plt.plot(seq, bandsMono.band16-Efermi, c='black')
plt.plot(seq, bandsMono.band17-Efermi, c='black')
plt.plot(seq, bandsMono.band18-Efermi, c='black')
plt.plot(seq, bandsMono.band19-Efermi, c='black')
plt.plot(seq, bandsMono.band20-Efermi, c='black')
plt.plot(seq, bandsMono.band21-Efermi, c='black')
plt.plot(seq, bandsMono.band22-Efermi, c='black')
plt.plot(seq, bandsMono.band23-Efermi, c='black')
plt.plot(seq, bandsMono.band24-Efermi, c='black')
plt.plot(seq, bandsMono.band25-Efermi, c='black')
plt.plot(seq, bandsMono.band26-Efermi, c='black')
plt.plot(seq, bandsMono.band27-Efermi, c='black')
plt.plot(seq, bandsMono.band28-Efermi, c='black')
plt.plot(seq, bandsMono.band29-Efermi, c='black')
plt.plot(seq, bandsMono.band30-Efermi, c='black')
plt.plot(seq, bandsMono.band31-Efermi, c='black')
plt.plot(seq, bandsMono.band32-Efermi, c='black')
plt.plot(seq, bandsMono.band33-Efermi, c='black')
plt.plot(seq, bandsMono.band34-Efermi, c='black')
plt.plot(seq, bandsMono.band35-Efermi, c='black')
plt.plot(seq, bandsMono.band36-Efermi, c='black')

plt.xlim(1,203)
plt.ylim(-10,5)
# Out:
# (-10.0, 5.0)

# %%
sym_mono = """0.0000000000     0.0000000000     0.0000000000   30   !Gamma
0.5000000000     0.0000000000     0.0000000000   15   !Y
0.5421686747    -0.3571428571     0.0000000000   10   !H
0.5000000000    -0.5000000000     0.0000000000   20   !C
0.5000000000    -0.5000000000     0.5000000000   10   !E
0.4578313253    -0.6428571429     0.5000000000   15   !M1
0.0000000000    -0.5000000000     0.5000000000   20   !A
0.0000000000    -0.5000000000     0.0000000000   15   !X
0.4578313253    -0.6428571429     0.0000000000   0    !H1
0.5421686747    -0.3571428571     0.5000000000   15   !M
0.5000000000     0.0000000000     0.5000000000   30   !D
0.0000000000     0.0000000000     0.5000000000   0    !Z
0.5000000000     0.0000000000     0.0000000000   20   !Y
0.5000000000     0.0000000000     0.5000000000   0    !D"""
sym_mono = sym_mono.split()
sym_mono
# Out:
# ['0.0000000000',
#  '0.0000000000',
#  '0.0000000000',
#  '30',
#  '!Gamma',
#  '0.5000000000',
#  '0.0000000000',
#  '0.0000000000',
#  '15',
#  '!Y',
#  '0.5421686747',
#  '-0.3571428571',
#  '0.0000000000',
#  '10',
#  '!H',
#  '0.5000000000',
#  '-0.5000000000',
#  '0.0000000000',
#  '20',
#  '!C',
#  '0.5000000000',
#  '-0.5000000000',
#  '0.5000000000',
#  '10',
#  '!E',
#  '0.4578313253',
#  '-0.6428571429',
#  '0.5000000000',
#  '15',
#  '!M1',
#  '0.0000000000',
#  '-0.5000000000',
#  '0.5000000000',
#  '20',
#  '!A',
#  '0.0000000000',
#  '-0.5000000000',
#  '0.0000000000',
#  '15',
#  '!X',
#  '0.4578313253',
#  '-0.6428571429',
#  '0.0000000000',
#  '0',
#  '!H1',
#  '0.5421686747',
#  '-0.3571428571',
#  '0.5000000000',
#  '15',
#  '!M',
#  '0.5000000000',
#  '0.0000000000',
#  '0.5000000000',
#  '30',
#  '!D',
#  '0.0000000000',
#  '0.0000000000',
#  '0.5000000000',
#  '0',
#  '!Z',
#  '0.5000000000',
#  '0.0000000000',
#  '0.0000000000',
#  '20',
#  '!Y',
# ...

# %%
sym_mono = np.reshape(sym_mono,(14,5))

# %%
for line in sym_mono:
  line[0] = float(line[0])
  line[1] = float(line[1])
  line[2] = float(line[2])
  line[3] = int(line[3])
  line[4] = line[4].strip('!')

# %%
sym_mono = pd.DataFrame(sym_mono)
sym_mono
# Out:
#                0              1    2   3      4
# 0            0.0            0.0  0.0  30  Gamma
# 1            0.5            0.0  0.0  15      Y
# 2   0.5421686747  -0.3571428571  0.0  10      H
# 3            0.5           -0.5  0.0  20      C
# 4            0.5           -0.5  0.5  10      E
# 5   0.4578313253  -0.6428571429  0.5  15     M1
# 6            0.0           -0.5  0.5  20      A
# 7            0.0           -0.5  0.0  15      X
# 8   0.4578313253  -0.6428571429  0.0   0     H1
# 9   0.5421686747  -0.3571428571  0.5  15      M
# 10           0.5            0.0  0.5  30      D
# 11           0.0            0.0  0.5   0      Z
# 12           0.5            0.0  0.0  20      Y
# 13           0.5            0.0  0.5   0      D

# %%
bandsMono.iloc[175:200,:]
# Out:
#      Unnamed: 0      xpos      ypos      zpos  ...  band33  band34  band35  band36
# 175         175  0.100000  0.019545  0.362713  ...  17.402  17.402  17.869  17.869
# 176         176  0.083333  0.016288  0.362713  ...  17.390  17.390  17.887  17.887
# 177         177  0.066667  0.013030  0.362713  ...  17.376  17.376  17.906  17.906
# 178         178  0.050000  0.009773  0.362713  ...  17.362  17.362  17.925  17.925
# 179         179  0.033333  0.006515  0.362713  ...  17.350  17.350  17.940  17.940
# 180         180  0.016667  0.003258  0.362713  ...  17.343  17.343  17.950  17.950
# 181         181  0.000000  0.000000  0.362713  ...  17.340  17.340  17.953  17.953
# 182         182  0.500000  0.097727  0.000000  ...  17.262  17.309  18.439  19.250
# 183         183  0.500000  0.097727  0.018136  ...  17.277  17.306  18.438  19.226
# 184         184  0.500000  0.097727  0.036271  ...  17.296  17.319  18.432  19.166
# ...

# %%
for i in range(len(sym_mono)):
  sym_mono.iloc[i,0] = float(sym_mono.iloc[i,0])
  sym_mono.iloc[i,1] = float(sym_mono.iloc[i,1])
  sym_mono.iloc[i,2] = float(sym_mono.iloc[i,2])
  sym_mono.iloc[i,3] = int(sym_mono.iloc[i,3])

# %%
for i in range(len(bandsMono)):
  for k in range(len(sym_mono)):
    compara = np.array(bandsMono.iloc[i,1:4]) == np.array(sym_mono.iloc[k,0:3])
    if compara.all():
      print("Ponto", sym_mono.iloc[k,4],"na linha",i)
# Out:
# Ponto Gamma na linha 0
